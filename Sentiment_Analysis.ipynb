# %% [markdown]
# # Sentiment Insight Analysis Project

# %% [markdown]
# ## Summary of the Project:
#
#
# ## 1. Project Overview
# The "Sentiment Insight Analysis Project" is an exploratory data analysis (EDA) project analyzing sentiment in Reddit comments. The notebook focuses on loading and inspecting a dataset of cleaned comments labeled as negative (-1), neutral (0), or positive (1), laying the groundwork for further sentiment analysis.
#
# ## 2. Objectives
# - Load the Reddit comment dataset.
# - Examine dataset structure, size, and sentiment distribution.
# - Identify issues (e.g., missing values) for preprocessing.
# - Prepare for subsequent analysis and modeling.
#
# ## 3. Dataset Description
# - **Source**: GitHub URL [Reddit Sentiment Dataset](`https://raw.githubusercontent.com/Himanshu-1703/reddit-sentiment-analysis/refs/heads/main/data/reddit.csv`).
# - **Structure**:
#   - **Rows**: 37,249
#   - **Columns**: 2 (`clean_comment`: text, `category`: sentiment labels [-1, 0, 1]).
# - **Key Statistics**:
#   - `clean_comment`: 100 missing values (37,149 non-null).
#   - `category`: No missing values; mean = 0.202771, indicating a slight positive/neutral skew.
#   - Standard deviation: 0.778515; percentiles suggest more neutral/positive comments.
#
# ## 4. Methodology
# 1. **Environment Setup**:
#    - Imported `pandas`, `numpy`, `matplotlib`, `seaborn`, and suppressed warnings.
# 2. **Data Loading**:
#    - Loaded dataset into a `pandas` DataFrame via `pd.read_csv`.
# 3. **Exploratory Data Analysis**:
#    - `df.head(10)`: Previewed first 10 rows.
#    - `df.shape`: Confirmed 37,249 rows, 2 columns.
#    - `df.info()`: Identified data types and 100 missing values in `clean_comment`.
#    - `df.describe()`: Showed slight positive sentiment bias in `category`.
#
# ## 5. Key Findings
# - Dataset is suitable for sentiment analysis with clear labels.
# - 100 missing values in `clean_comment` need handling.
# - Sentiment distribution leans positive/neutral, potentially requiring balancing.
# - Notebook is limited to basic EDA without preprocessing or visualization.
#
# ## 6. Tools and Libraries
# - **Libraries**: `pandas` (data handling), `numpy` (numerical operations), `matplotlib`/`seaborn` (unused for visualization).
# - **Environment**: Google Colab (inferred from metadata).
#
# ## 7. Limitations
# - Only basic EDA (`head`, `shape`, `info`, `describe`) performed.
# - Missing values in `clean_comment` not addressed.
# - No visualizations despite imported libraries.
# - Lacks preprocessing, feature engineering, or modeling.
#
# ## 8. Future Work
# - Clean missing values in `clean_comment`.
# - Visualize sentiment distribution and text patterns.
# - Preprocess text (e.g., tokenization, stopword removal).
# - Engineer features (e.g., TF-IDF, embeddings).
# - Train and evaluate sentiment models (e.g., logistic regression, BERT).
#
# ## 9. Conclusion
# The notebook provides a foundation for sentiment analysis by loading and inspecting the Reddit dataset. It identifies key characteristics like missing values and sentiment skew but is limited to basic EDA. Future steps include cleaning, visualization, and modeling to achieve comprehensive sentiment insights.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Importing all necessary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Himanshu-1703/reddit-sentiment-analysis/refs/heads/main/data/reddit.csv')
df.head(10)
# Out:
#                                        clean_comment  category
# 0   family mormon have never tried explain them t...         1
# 1  buddhism has very much lot compatible with chr...         1
# 2  seriously don say thing first all they won get...        -1
# 3  what you have learned yours and only yours wha...         0
# 4  for your own benefit you may want read living ...         1
# 5  you should all sit down together and watch the...        -1
# 6   was teens when discovered zen meditation was ...         1
# 7                           jesus was zen meets jew          0
# 8  there are two varieties christians dogmatic th...        -1
# 9  dont worry about trying explain yourself just ...         1

# %%
df.shape
# Out:
# (37249, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37249 entries, 0 to 37248
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clean_comment  37149 non-null  object
#  1   category       37249 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 582.1+ KB

# %%
df.describe()
# Out:
#            category
# count  37249.000000
# mean       0.202771
# std        0.778515
# min       -1.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.dtypes
# Out:
# clean_comment    object
# category          int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# clean_comment    100
# category           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df[df.duplicated()]
# Out:
#                                            clean_comment  category
# 375                                                              0
# 392                                                              0
# 617                                           aurum mom          0
# 651                                                              0
# 1222                                                             0
# ...                                                  ...       ...
# 36915                                           who won          0
# 37044                                                            0
# 37125                                              hari          0
# 37158                                           top kek          1
# 37234  this part series minute videos focusing each d...         1
#
# [350 rows x 2 columns]

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[(df['clean_comment'].str.strip() == '')]
# Out:
#                 clean_comment  category
# 181                                   0
# 4432                       \n         0
# 10592                                 0
# 16173                                 0
# 32149  \n                             0
# 34959                                 0

# %% [markdown]
# ### Convert the 'clean_comment' column to lowercase

# %%
df['clean_comment'] = df['clean_comment'].str.lower()

df.head(10)
# Out:
#                                        clean_comment  category
# 0   family mormon have never tried explain them t...         1
# 1  buddhism has very much lot compatible with chr...         1
# 2  seriously don say thing first all they won get...        -1
# 3  what you have learned yours and only yours wha...         0
# 4  for your own benefit you may want read living ...         1
# 5  you should all sit down together and watch the...        -1
# 6   was teens when discovered zen meditation was ...         1
# 7                           jesus was zen meets jew          0
# 8  there are two varieties christians dogmatic th...        -1
# 9  dont worry about trying explain yourself just ...         1

# %% [markdown]
# ### Remove trailing and leading whitespaces from the 'clean_comment' column

# %%
# Remove trailing and leading whitespaces from the 'clean_comment' column
df['clean_comment'] = df['clean_comment'].str.strip()


# Verify the transformation by checking for any remaining trailing whitespaces
df['clean_comment'].apply(lambda x: x.endswith(' ') or x.startswith(' ')).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Identify comments containing URLs

# %%
# Identify comments containing URLs
url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
comments_with_urls = df[df['clean_comment'].str.contains(url_pattern, regex=True)]


# Display the comments containing URLs
comments_with_urls.head()
# Out:
# Empty DataFrame
# Columns: [clean_comment, category]
# Index: []

# %% [markdown]
# ### Identify comments containing new line characters

# %%
# Identify comments containing new line characters
comments_with_newline = df[df['clean_comment'].str.contains('\n')]

# Display the comments containing new line characters
comments_with_newline.head()
# Out:
#                                           clean_comment  category
# 448   what missing jpg\nand why this brilliant edit ...         1
# 781   india has been ruined congress and populist sc...        -1
# 847   like aap for its stand corruption and making p...        -1
# 871   reduced trade\ndeficit stronger rupee aren the...         0
# 1354  amsa press conference australian maritime safe...         1

# %% [markdown]
# ### Remove new line characters from the 'clean_comment' column

# %%
# Remove new line characters from the 'clean_comment' column
df['clean_comment'] = df['clean_comment'].str.replace('\n', ' ', regex=True)

# Verify the transformation by checking for any remaining new lines
comments_with_newline_remaining = df[df['clean_comment'].str.contains('\n')]
comments_with_newline_remaining
# Out:
# Empty DataFrame
# Columns: [clean_comment, category]
# Index: []

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Distribution of Categories (Count Plot)

# %%
sns.set(style="whitegrid", palette="pastel")
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='category', data=df, palette='Set2', edgecolor='black')

# Add value labels on top
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2., height + 1, int(height), ha="center", fontsize=12, fontweight='bold')

# Titles and labels
plt.title('Distribution of Categories', fontsize=18, fontweight='bold')
plt.xlabel('Category', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# layout
plt.tight_layout()
plt.show()

# %%
df['word_count'] = df['clean_comment'].apply(lambda x: len(x.split()))

df.head()
# Out:
#                                        clean_comment  category  word_count
# 0  family mormon have never tried explain them th...         1          39
# 1  buddhism has very much lot compatible with chr...         1         196
# 2  seriously don say thing first all they won get...        -1          86
# 3  what you have learned yours and only yours wha...         0          29
# 4  for your own benefit you may want read living ...         1         112

# %% [markdown]
# ### Distribution of Word Count (Hist plot)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))
sns.histplot(df['word_count'], kde=True, color='crimson', edgecolor='black')

# Title and labels
plt.title('Distribution of Word Count', fontsize=14, fontweight='bold')
plt.xlabel('Words Count', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Word Count Distribution by Category (KDE Plot)

# %%
plt.figure(figsize=(10, 6))

# Plot KDE for category 1
sns.kdeplot(df[df['category'] == 1]['word_count'], label='Positive', fill=True)

# Plot KDE for category 0
sns.kdeplot(df[df['category'] == 0]['word_count'], label='Neutral', fill=True)

# Plot KDE for category -1
sns.kdeplot(df[df['category'] == -1]['word_count'], label='Negative', fill=True)


plt.title('Word Count Distribution by Category')
plt.xlabel('Word Count')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# **Positive comments (category 1)**: These tend to have a wider spread in word count, indicating that longer comments are more common in positive sentiments.<br>
# **Neutral comments (category 0)**: The distribution shows a relatively lower frequency and is more concentrated around shorter comments compared to positive or negative ones.<br>
# **Negative comments (category -1)**: These comments have a distribution somewhat similar to positive comments but with a smaller proportion of longer comments.

# %% [markdown]
# ### Distribution of Word Count per Record (Box Plot)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['word_count'], color='lightgreen')
plt.title('Distribution of Word Count per Record', fontsize=14, fontweight='bold')
plt.xlabel('Word Count', fontsize=12)
plt.grid(True, axis='x', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Word Count Distribution by Category (Box Plot)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='category', y='word_count', palette='Set2')

plt.title('Word Count Distribution by Category', fontsize=16, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Word Count', fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Positive comments (category 1)**: The median word count is relatively high, and there are several outliers with longer comments, indicating that positive comments tend to be more verbose.<br>
# **Neutral comments (category 0)**: The median word count is the lowest, with a tighter interquartile range (IQR), suggesting that neutral comments are generally shorter.<br>
# **Negative comments (category -1)**: The word count distribution is similar to positive comments but with a slightly lower median and fewer extreme outliers.

# %% [markdown]
# ### Word Count Distribution by Category (Strip Plot)

# %%
plt.figure(figsize=(12, 6))
sns.stripplot(data=df, x='category', y='word_count', alpha=0.6, jitter=True, palette='Set2')

plt.title('Word Count Distribution by Category', fontsize=16, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Word Count', fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Median Word Count by Category (Bar Plot)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='category', y='word_count', estimator='median', palette='Set3')

plt.title('Median Word Count by Category', fontsize=16, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Median Word Count', fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a new column 'num_stop_words' by counting the number of stopwords in each comment

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

# Define the list of English stopwords
stop_words = set(stopwords.words('english'))

# Create a new column 'num_stop_words' by counting the number of stopwords in each comment
df['num_stop_words'] = df['clean_comment'].apply(lambda x: len([word for word in x.split() if word in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.head(10)
# Out:
#                                        clean_comment  category  word_count  \
# 0  family mormon have never tried explain them th...         1          39
# 1  buddhism has very much lot compatible with chr...         1         196
# 2  seriously don say thing first all they won get...        -1          86
# 3  what you have learned yours and only yours wha...         0          29
# 4  for your own benefit you may want read living ...         1         112
# 5  you should all sit down together and watch the...        -1          23
# 6  was teens when discovered zen meditation was t...         1         155
# 7                            jesus was zen meets jew         0           5
# 8  there are two varieties christians dogmatic th...        -1          82
# 9  dont worry about trying explain yourself just ...         1          31
#
#    num_stop_words
# 0              13
# 1              59
# 2              40
# 3              15
# 4              45
# 5               9
# 6              58
# 7               1
# 8              30
# 9              13

# %% [markdown]
# ### Create a distribution plot (displot) for the 'num_stop_words' column

# %%
# Create a distribution plot (displot) for the 'num_stop_words' column
plt.figure(figsize=(10, 6))
sns.histplot(df['num_stop_words'], kde=True)
plt.title('Distribution of Stop Word Count in Comments')
plt.xlabel('Number of Stop Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Num stop words Distribution by Category

# %%
plt.figure(figsize=(10, 6))

# Plot KDE for category 1
sns.kdeplot(df[df['category'] == 1]['num_stop_words'], label='Positive', fill=True)

# Plot KDE for category 0
sns.kdeplot(df[df['category'] == 0]['num_stop_words'], label='Neutral', fill=True)

# Plot KDE for category -1
sns.kdeplot(df[df['category'] == -1]['num_stop_words'], label='Negative', fill=True)

# Add title and labels
plt.title('Num stop words Distribution by Category')
plt.xlabel('Stop word count')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ### Median Word Counts Among Sentiments

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='category', y='num_stop_words', estimator='median', palette='Set3')

plt.title('Median Word Counts Among Sentiments', fontsize=16, fontweight='bold')
plt.xlabel('num_stop_words', fontsize=12)
plt.ylabel('Median Word Count', fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 25 Most Common Stop Words

# %%
# Create a frequency distribution of stop words in the 'clean_comment' column
from collections import Counter

# Extract all stop words from the comments using the previously defined 'common_stopwords'
all_stop_words = [word for comment in df['clean_comment'] for word in comment.split() if word in stop_words]

# Count the most common stop words
most_common_stop_words = Counter(all_stop_words).most_common(25)

# Convert the most common stop words to a DataFrame for plotting
top_25_df = pd.DataFrame(most_common_stop_words, columns=['stop_word', 'count'])

# Create the barplot for the top 25 most common stop words
plt.figure(figsize=(12, 8))
sns.barplot(data=top_25_df, x='count', y='stop_word', palette='viridis')
plt.title('Top 25 Most Common Stop Words')
plt.xlabel('Count')
plt.ylabel('Stop Word')
plt.show()

# %% [markdown]
# ### Number of Character

# %%
df['num_chars'] = df['clean_comment'].apply(len)

df.head(10)
# Out:
#                                        clean_comment  category  word_count  \
# 0  family mormon have never tried explain them th...         1          39
# 1  buddhism has very much lot compatible with chr...         1         196
# 2  seriously don say thing first all they won get...        -1          86
# 3  what you have learned yours and only yours wha...         0          29
# 4  for your own benefit you may want read living ...         1         112
# 5  you should all sit down together and watch the...        -1          23
# 6  was teens when discovered zen meditation was t...         1         155
# 7                            jesus was zen meets jew         0           5
# 8  there are two varieties christians dogmatic th...        -1          82
# 9  dont worry about trying explain yourself just ...         1          31
#
#    num_stop_words  num_chars
# 0              13        259
# 1              59       1268
# 2              40        459
# 3              15        167
# 4              45        690
# 5               9        145
# 6              58        963
# 7               1         23
# 8              30        552
# 9              13        192

# %%
df['num_chars'].describe()
# Out:
# count    36799.000000
# mean       181.823147
# std        359.680331
# min          0.000000
# 25%         38.000000
# 50%         80.000000
# 75%        184.000000
# max       8664.000000
# Name: num_chars, dtype: float64

# %% [markdown]
# ### Combine all comments into one large string

# %%
# Combine all comments into one large string
all_text = ' '.join(df['clean_comment'])

# Count the frequency of each character
char_frequency = Counter(all_text)

# Convert the character frequency into a DataFrame for better display
char_frequency_df = pd.DataFrame(char_frequency.items(),
                                 columns=['character', 'frequency']).sort_values(by='frequency',
                                                                                 ascending=False)

# %%
char_frequency_df['character'].values
# Out:
# array([' ', 'e', 't', ..., '段', '她', '谁'], dtype=object)

# %% [markdown]
# ### Create a new column 'num_punctuation_chars' to count punctuation characters in each comment

# %%
# Create a new column 'num_punctuation_chars' to count punctuation characters in each comment
df['num_punctuation_chars'] = df['clean_comment'].apply(
    lambda x: sum([1 for char in x if char in '.,!?;:"\'()[]{}-'])
)

df.sample(5)
# Out:
#                                            clean_comment  category  \
# 16893                        share randia link the tweet         0
# 2657                                          there hope         0
# 816                         critical issue lol one cares         1
# 36214  nothing with cricket sachin biopic producers r...         0
# 604                                                  cut         0
#
#        word_count  num_stop_words  num_chars  num_punctuation_chars
# 16893           5               1         27                      0
# 2657            2               1         10                      0
# 816             5               0         28                      0
# 36214           8               1         55                      0
# 604             1               0          3                      0

# %%
df['num_punctuation_chars'].describe()
# Out:
# count    36799.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: num_punctuation_chars, dtype: float64

# %% [markdown]
# ### Top 25 Most Common Bigrams

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Create a function to extract the top 25 bigrams
def get_top_ngrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# Get the top 25 bigrams
top_25_bigrams = get_top_ngrams(df['clean_comment'], 25)

# Convert the bigrams into a DataFrame for plotting
top_25_bigrams_df = pd.DataFrame(top_25_bigrams, columns=['bigram', 'count'])

# Plot the countplot for the top 25 bigrams
plt.figure(figsize=(12, 8))
sns.barplot(data=top_25_bigrams_df, x='count', y='bigram', palette='magma')
plt.title('Top 25 Most Common Bigrams')
plt.xlabel('Count')
plt.ylabel('Bigram')
plt.show()

# %% [markdown]
# ### Top 25 Most Common Trigrams

# %%
# Create a function to extract the top 25 trigrams
def get_top_trigrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# Get the top 25 trigrams
top_25_trigrams = get_top_trigrams(df['clean_comment'], 25)

# Convert the trigrams into a DataFrame for plotting
top_25_trigrams_df = pd.DataFrame(top_25_trigrams, columns=['trigram', 'count'])

# Plot the countplot for the top 25 trigrams
plt.figure(figsize=(12, 8))
sns.barplot(data=top_25_trigrams_df, x='count', y='trigram', palette='coolwarm')
plt.title('Top 25 Most Common Trigrams')
plt.xlabel('Count')
plt.ylabel('Trigram')
plt.show()

# %% [markdown]
# ### Remove non-English characters from the 'clean_comment' column

# %%
# Keeping only standard English letters, digits, and common punctuation
import re

df['clean_comment'] = df['clean_comment'].apply(lambda x: re.sub(r'[^A-Za-z0-9\s!?.,]', '', str(x)))

# %%
all_text = ' '.join(df['clean_comment'])

# Count the frequency of each character
char_frequency = Counter(all_text)

# Convert the character frequency into a DataFrame for better display
char_frequency_df = pd.DataFrame(char_frequency.items(), columns=['character', 'frequency']).sort_values(by='frequency', ascending=False)

char_frequency_df
# Out:
#    character  frequency
# 6               1091598
# 12         e     666610
# 13         t     491287
# 1          a     481134
# 3          i     401388
# 9          n     388465
# 7          o     379908
# 17         s     355279
# 8          r     331425
# 10         h     296748
# 4          l     250104
# 14         d     221980
# 18         u     170377
# 22         c     167821
# 2          m     155561
# 16         p     135139
# 21         g     132927
# 5          y     115420
# 25         w     110522
# 24         b      88199
# 0          f      78866
# 11         v      66020
# 20         k      62531
# 26         j      22906
# 15         x       9075
# 30         0       8477
# 19         z       5725
# 23         q       5136
# 31         1       4845
# 32         2       4638
# 34         9       1775
# 27         5       1631
# 35         3       1617
# 29         4       1573
# 28         6       1403
# 36         7       1291
# 33         8       1199
# 38                   76
# 37        \t         11
# 40                    3
# 39                    1

# %%
# Defining stop words but keeping essential ones for sentiment analysis
stop_words = set(stopwords.words('english')) - {'not', 'but', 'however', 'no', 'yet'}

# Remove stop words from 'clean_comment' column, retaining essential ones
df['clean_comment'] = df['clean_comment'].apply(
    lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words])
)

# %%
df.head(10)
# Out:
#                                        clean_comment  category  word_count  \
# 0  family mormon never tried explain still stare ...         1          39
# 1  buddhism much lot compatible christianity espe...         1         196
# 2  seriously say thing first get complex explain ...        -1          86
# 3  learned want teach different focus goal not wr...         0          29
# 4  benefit may want read living buddha living chr...         1         112
# 5  sit together watch simpsons episode lisa becom...        -1          23
# 6  teens discovered zen meditation undiagnosed bp...         1         155
# 7                                jesus zen meets jew         0           5
# 8  two varieties christians dogmatic dwell words ...        -1          82
# 9  dont worry trying explain meditate regularly t...         1          31
#
#    num_stop_words  num_chars  num_punctuation_chars
# 0              13        259                      0
# 1              59       1268                      0
# 2              40        459                      0
# 3              15        167                      0
# 4              45        690                      0
# 5               9        145                      0
# 6              58        963                      0
# 7               1         23                      0
# 8              30        552                      0
# 9              13        192                      0

# %% [markdown]
# ### Lemmatization to the 'clean_comment_no_stopwords' column

# %%
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

# Define the lemmatizer
lemmatizer = WordNetLemmatizer()

# Apply lemmatization to the 'clean_comment_no_stopwords' column
df['clean_comment'] = df['clean_comment'].apply(
    lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()])
)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df.head(10)
# Out:
#                                        clean_comment  category  word_count  \
# 0  family mormon never tried explain still stare ...         1          39
# 1  buddhism much lot compatible christianity espe...         1         196
# 2  seriously say thing first get complex explain ...        -1          86
# 3  learned want teach different focus goal not wr...         0          29
# 4  benefit may want read living buddha living chr...         1         112
# 5  sit together watch simpson episode lisa become...        -1          23
# 6  teen discovered zen meditation undiagnosed bpd...         1         155
# 7                                 jesus zen meet jew         0           5
# 8  two variety christian dogmatic dwell word cons...        -1          82
# 9  dont worry trying explain meditate regularly t...         1          31
#
#    num_stop_words  num_chars  num_punctuation_chars
# 0              13        259                      0
# 1              59       1268                      0
# 2              40        459                      0
# 3              15        167                      0
# 4              45        690                      0
# 5               9        145                      0
# 6              58        963                      0
# 7               1         23                      0
# 8              30        552                      0
# 9              13        192                      0

# %%
from wordcloud import WordCloud

def plot_word_cloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

plot_word_cloud(df['clean_comment'])

# %%
 def plot_word_cloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

plot_word_cloud(df[df['category'] == 1]['clean_comment'])

# %%
def plot_word_cloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

plot_word_cloud(df[df['category'] == 0]['clean_comment'])

# %%
def plot_word_cloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

plot_word_cloud(df[df['category'] == -1]['clean_comment'])

# %% [markdown]
# ### Top N most frequent words in the dataset

# %%
def plot_top_n_words(df, n=20):
    """Plot the top N most frequent words in the dataset."""
    # Flatten all words in the content column
    words = ' '.join(df['clean_comment']).split()

    # Get the top N most common words
    counter = Counter(words)
    most_common_words = counter.most_common(n)

    # Split the words and their counts for plotting
    words, counts = zip(*most_common_words)

    # Plot the top N words
    plt.figure(figsize=(10, 6))
    sns.barplot(x=list(counts), y=list(words))
    plt.title(f'Top {n} Most Frequent Words')
    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.show()

# Example usage
plot_top_n_words(df, n=50)

# %% [markdown]
# ### Top Most Frequent Words with Stacked Sentiment Categories

# %%
def plot_top_n_words_by_category(df, n=20, start=0):
    """Plot the top N most frequent words in the dataset with stacked hue based on sentiment category."""
    # Flatten all words in the content column and count their occurrences by category
    word_category_counts = {}

    for idx, row in df.iterrows():
        words = row['clean_comment'].split()
        category = row['category']  # Assuming 'category' column exists for -1, 0, 1 labels

        for word in words:
            if word not in word_category_counts:
                word_category_counts[word] = { -1: 0, 0: 0, 1: 0 }  # Initialize counts for each sentiment category

            # Increment the count for the corresponding sentiment category
            word_category_counts[word][category] += 1

    # Get total counts across all categories for each word
    total_word_counts = {word: sum(counts.values()) for word, counts in word_category_counts.items()}

    # Get the top N most frequent words across all categories
    most_common_words = sorted(total_word_counts.items(), key=lambda x: x[1], reverse=True)[start:start+n]
    top_words = [word for word, _ in most_common_words]

    # Prepare data for plotting
    word_labels = top_words
    negative_counts = [word_category_counts[word][-1] for word in top_words]
    neutral_counts = [word_category_counts[word][0] for word in top_words]
    positive_counts = [word_category_counts[word][1] for word in top_words]

    # Plot the stacked bar chart
    plt.figure(figsize=(12, 8))
    bar_width = 0.75

    # Plot negative, neutral, and positive counts in a stacked manner
    plt.barh(word_labels, negative_counts, color='red', label='Negative (-1)', height=bar_width)
    plt.barh(word_labels, neutral_counts, left=negative_counts, color='gray', label='Neutral (0)', height=bar_width)
    plt.barh(word_labels, positive_counts, left=[i+j for i,j in zip(negative_counts, neutral_counts)], color='green', label='Positive (1)', height=bar_width)

    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.title(f'Top {n} Most Frequent Words with Stacked Sentiment Categories')
    plt.legend(title='Sentiment', loc='lower right')
    plt.gca().invert_yaxis()  # Invert y-axis to show the highest frequency at the top
    plt.show()



plot_top_n_words_by_category(df, n=20)
